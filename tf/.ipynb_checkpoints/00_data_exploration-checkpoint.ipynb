# %%
import numpy as np 
import pandas as pd 
import os 

DATA_LOCATION="/home/sharath/resources/data/kaggle/zindi/fruit_disease_detection"
META_DATA_CSV="Train.csv"
TRAIN_IMAGES_DIR="Train_Images"
meta_df=pd.read_csv(os.path.join(DATA_LOCATION,META_DATA_CSV))
meta_df.head()
# Out:
#       Image_ID            class   xmin   ymin  width  height
# 0  ID_007FAIEI  fruit_woodiness   87.0   87.5  228.0   311.0
# 1  ID_00G8K1V3  fruit_brownspot   97.5   17.5  245.0   354.5
# 2  ID_00WROUT9  fruit_brownspot  156.5  209.5  248.0   302.5
# 3  ID_00ZJEEK3    fruit_healthy  125.0  193.0  254.5   217.0
# 4  ID_018UIENR  fruit_brownspot   79.5  232.5  233.5   182.0

# %%
meta_df['class'].unique()
# Out:
# array(['fruit_woodiness', 'fruit_brownspot', 'fruit_healthy'],
#       dtype=object)

# %%
meta_df[meta_df['class']=='fruit_woodiness'].loc[0].Image_ID
# Out:
# 'ID_007FAIEI'

# %%
import plotly.io as pio
import plotly.express as px
from skimage import io


woodiness_ex=os.path.join(DATA_LOCATION,TRAIN_IMAGES_DIR,meta_df[meta_df['class']=='fruit_woodiness'].loc[0].Image_ID+".jpg")
img = io.imread(woodiness_ex)
print(woodiness_ex)
# print(img)
px.imshow(img).show()
# Out:
# /home/sharath/resources/data/kaggle/zindi/fruit_disease_detection/Train_Images/ID_007FAIEI.jpg

# %%
brownspot_ex=os.path.join(DATA_LOCATION,TRAIN_IMAGES_DIR,meta_df[meta_df['class']=='fruit_brownspot'].loc[0].Image_ID+".jpg")
img = io.imread(brownspot_ex)
print(brownspot_ex)
# print(img)
px.imshow(img).show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_27541/3830194041.py in <module>
# ----> 1 brownspot_ex=os.path.join(DATA_LOCATION,TRAIN_IMAGES_DIR,meta_df[meta_df['class']=='fruit_brownspot'].loc[0].Image_ID+".jpg")
#       2 img = io.imread(brownspot_ex)
#       3 print(brownspot_ex)
#       4 # print(img)
#       5 px.imshow(img).show()
#
# NameError: name 'os' is not defined
